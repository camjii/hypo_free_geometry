# %%
import sys, os
sys.path.insert(0, '/Users/cameronkruger/hypo_free_geometry_recovery/workingcodebase')

from pipeline_draft import Pipeline
import numpy as np

# %%
# Sorted by longitude
states_prompts = [
    'Hawaii', 'Alaska', 'Washington', 'Oregon', 'California', 'Nevada', 'Idaho', 'Arizona', 'Utah', 'Montana', 'Wyoming',
    'New Mexico', 'Colorado', 'North Dakota', 'South Dakota', 'Nebraska', 'Texas', 'Kansas', 'Oklahoma', 'Minnesota',
    'Iowa', 'Missouri', 'Arkansas', 'Louisiana', 'Mississippi', 'Wisconsin', 'Illinois', 'Alabama', 'Tennessee', 'Indiana',
    'Michigan', 'Kentucky', 'Georgia', 'Ohio', 'Florida', 'South Carolina', 'West Virginia', 'North Carolina', 'Virginia',
    'Pennsylvania', 'Maryland', 'Delaware', 'New York', 'New Jersey', 'Connecticut', 'Vermont', 'Massachusetts', 'New Hampshire',
    'Rhode Island', 'Maine'
]


states_contextualized_prompts = [f"The location of the US state {st}" for st in states_prompts]

months_prompts = ["January", "February","March","April","May","June","July","August","September","October","November","December"]
months_contextualized_prompts = [f"The month of the year is {s}" for s in months_prompts]

years_prompts = [str(i) for i in range(1700, 2022)]
years_contextualized_prompts = [f"In the year {s}" for s in years_prompts]

# %%
months = Pipeline(months_contextualized_prompts)
# Out:
# Loading weights: 100%|██████████| 288/288 [00:00<00:00, 9907.40it/s]
# WARNING:root:You tried to specify center_unembed=True for a model using logit softcap, but this can't be done! Softcapping is not invariant upon adding a constant Setting center_unembed=False instead.
# WARNING:root:With reduced precision, it is advised to use `from_pretrained_no_processing` instead of `from_pretrained`.
# Loaded pretrained model gemma-2-2b into HookedTransformer

# %%
best_layer, activations, scores = months.select_layer_by_topology()
# Out:
# Intrinsic dimension (TwoNN): 9.48
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.09
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.82
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.07
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 8.82
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.16
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.60
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.11
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 10.89
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 7.98
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.73
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 4.96
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 11.68
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 7.97
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.67
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 4.99
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 14.48
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.04
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 8.23
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.61
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 16.03
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.09
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 8.26
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.50
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 12.61
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 7.83
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 8.20
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.24
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 12.63
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.11
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.91
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.57
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 13.12
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.14
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.95
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.56
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 13.04
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.23
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 8.00
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.63
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 12.63
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.32
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.99
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.70
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 12.02
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.39
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.71
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.57
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 11.60
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.51
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.68
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.61
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 11.01
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.43
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.66
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.56
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 6.84
# PCA: keeping m=9 components (95% variance)
# Intrinsic dimension (TwoNN): 8.40
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.60
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 6.11
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 17.81
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.20
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.39
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.38
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 12.43
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.23
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.39
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.11
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 9.82
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.52
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.14
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 4.74
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 15.16
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 9.81
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.10
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 4.72
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 7.77
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.67
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.56
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.30
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 10.37
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 8.26
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.25
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 4.87
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 8.95
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 7.84
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.02
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.16
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 9.27
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 7.61
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 6.85
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.09
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 11.63
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 7.96
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.07
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.36
# PCA: keeping m=8 components (95% variance)
# Intrinsic dimension (TwoNN): 10.40
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 7.36
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 6.93
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 5.20
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 13.73
# PCA: keeping m=10 components (95% variance)
# Intrinsic dimension (TwoNN): 6.76
# PCA: keeping m=7 components (95% variance)
# Intrinsic dimension (TwoNN): 7.22
# PCA: keeping m=6 components (95% variance)
# Intrinsic dimension (TwoNN): 4.93
# PCA: keeping m=7 components (95% variance)
# Layer with the strongest topology-vs-null signal is layer_24 (topology=0.0450)

# %%
best_layer
# Out:
# 'layer_24'

# %%
pca = months.plot_pca(activations)
# Out:
# Saved PCA plot to pca_projection.png

# %%
baseline_months = np.load('months_contextualized_reps_by_layer.npy', allow_pickle=True)

# %%
baseline_months
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 baseline_months[0]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
